# %%
pip install prophet

# %%
import numpy as np
import pandas as pd

from prophet import Prophet

import warnings
warnings.filterwarnings("ignore")

# %%
train = pd.read_csv('/kaggle/input/forecast/Train (11).csv')
sample_submission = pd.read_csv('/kaggle/input/forecast/SampleSubmission (18).csv')
train.shape, sample_submission.shape
# Out:
# ((289926, 19), (370, 2))

# %%
train["currency"].value_counts()

# %% [markdown]
# # Data preprocessing

# %%
# train data
train['date'] = pd.to_datetime(train['date']) # convert data to datetime object
train.rename(columns={'date': 'ds', 'clicks': 'y'}, inplace=True) # the model expects the date and target features name to be 'ds', 'y' respectively
train_grouped = train.groupby(['ID', 'ds'])['y'].sum().to_frame() # we predict for each ID, so it is ideal we group by ID's
train_grouped
# Out:
#                                            y
# ID                          ds
# ID_5da86e71bf5dee4cf5047046 2020-01-01  36.0
#                             2020-01-02  50.0
#                             2020-01-03  54.0
#                             2020-01-04  47.0
#                             2020-01-05  59.0
# ...                                      ...
# ID_65b0f65c7fe62e56c5593d55 2024-02-09  37.0
#                             2024-02-10  55.0
#                             2024-02-11  94.0
#                             2024-02-12  78.0
#                             2024-02-13  74.0
#
# [67968 rows x 1 columns]

# %%
# test data
# the dates to predicts from are in sample_submission['ID'] e.g. ID_5da86e71bf5dee4cf5047046_2024_01_22, so we extract them.
test = sample_submission['ID'].copy()
test = test.to_frame()

target_dates = []
for id in test.ID:
  date = id[-10:]
  target_dates.append(date)

test['ds'] = target_dates
test['ds'] = pd.to_datetime(test['ds'], format='%Y_%m_%d')
test.drop(['ID'], axis=1, inplace=True)
test.head()
# Out:
#           ds
# 0 2024-01-22
# 1 2024-01-29
# 2 2024-02-21
# 3 2024-02-28
# 4 2023-12-04

# %% [markdown]
# # Forcasting with Prophet

# %%
from prophet.make_holidays import make_holidays_df
from prophet.diagnostics import cross_validation

# %%
horizon_days = int(0.25 * 1461)  # 25% of the initial period
horizon = f'{horizon_days} days'

# %%
horizon

# %%
def forecast_for_id(train_data, test_data, id):
    train_id = train_data.loc[id].reset_index()

    train_id.columns = ['ds', 'y']
    
    #holidays = make_holidays_df(year_list=[2020, 2021, 2022,2023,2024],country='US')

    model = Prophet(n_changepoints=27,changepoint_prior_scale=0.08,changepoint_range=0.5,
                    seasonality_prior_scale=7, holidays_prior_scale=7,
                      )
    
    
   # model.add_country_holidays(country_name='US')
   # model.add_seasonality(name='weekly', period=7, fourier_order=1)
    model.fit(train_id)
    
    #cv_results = cross_validation(model)

    # forecast for the next 2 dates in test data
    future_dates = test_data.iloc[:2]
    future_dates.columns = ['ds']
    forecast = model.predict(future_dates)

    return forecast[['ds', 'yhat']]

# now we loop over unique IDs in train data and forecast
forecasts = []
for id in train_grouped.index.levels[0]:
    forecasts.append(forecast_for_id(train_grouped, test, id))


all_forecasts = pd.concat(forecasts) # concatenate forecasts for all ID's
test['target'] = all_forecasts['yhat'].values # add predicted values to test data

# %%
from statsmodels.tsa.arima.model import ARIMA

def forecast_for_id(train_data, test_data, id):
    train_id = train_data.loc[id].reset_index()
    train_id.columns = ['ds', 'y']

    # Train ARIMA model
    model = ARIMA(train_id['y'], order=(5,1,0))  # Example order: ARIMA(5,1,0)
    model_fit = model.fit()

    # Forecast for the next 2 dates in test data
    future_dates = test_data.iloc[:2]
    future_dates.columns = ['ds']
    forecast = model_fit.forecast(steps=2)  # Forecast 2 steps ahead

    # Convert forecast to DataFrame
    forecast_df = pd.DataFrame({'ds': future_dates['ds'].values, 'yhat': forecast})

    return forecast_df

# now we loop over unique IDs in train data and forecast
forecasts = []
for id in train_grouped.index.levels[0]:
    forecasts.append(forecast_for_id(train_grouped, test, id))

all_forecasts = pd.concat(forecasts)  # concatenate forecasts for all IDs

test['target'] = all_forecasts['yhat'].values  # add predicted values to test data

# %%
pip install pmdarima
# Out:
# Collecting pmdarima
#   Downloading pmdarima-2.0.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_28_x86_64.whl.metadata (7.8 kB)
# Requirement already satisfied: joblib>=0.11 in /opt/conda/lib/python3.10/site-packages (from pmdarima) (1.4.0)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in /opt/conda/lib/python3.10/site-packages (from pmdarima) (3.0.8)
# Requirement already satisfied: numpy>=1.21.2 in /opt/conda/lib/python3.10/site-packages (from pmdarima) (1.26.4)
# Requirement already satisfied: pandas>=0.19 in /opt/conda/lib/python3.10/site-packages (from pmdarima) (2.1.4)
# Requirement already satisfied: scikit-learn>=0.22 in /opt/conda/lib/python3.10/site-packages (from pmdarima) (1.2.2)
# Requirement already satisfied: scipy>=1.3.2 in /opt/conda/lib/python3.10/site-packages (from pmdarima) (1.11.4)
# Requirement already satisfied: statsmodels>=0.13.2 in /opt/conda/lib/python3.10/site-packages (from pmdarima) (0.14.1)
# Requirement already satisfied: urllib3 in /opt/conda/lib/python3.10/site-packages (from pmdarima) (1.26.18)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in /opt/conda/lib/python3.10/site-packages (from pmdarima) (69.0.3)
# Requirement already satisfied: packaging>=17.1 in /opt/conda/lib/python3.10/site-packages (from pmdarima) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging>=17.1->pmdarima) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.10/site-packages (from pandas>=0.19->pmdarima) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas>=0.19->pmdarima) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /opt/conda/lib/python3.10/site-packages (from pandas>=0.19->pmdarima) (2023.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn>=0.22->pmdarima) (3.2.0)
# Requirement already satisfied: patsy>=0.5.4 in /opt/conda/lib/python3.10/site-packages (from statsmodels>=0.13.2->pmdarima) (0.5.6)
# Requirement already satisfied: six in /opt/conda/lib/python3.10/site-packages (from patsy>=0.5.4->statsmodels>=0.13.2->pmdarima) (1.16.0)
# Downloading pmdarima-2.0.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_28_x86_64.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 39.1 MB/s eta 0:00:0000:01
# Installing collected packages: pmdarima
# Successfully installed pmdarima-2.0.4
# Note: you may need to restart the kernel to use updated packages.

# %%
from pmdarima import auto_arima
from sklearn.model_selection import TimeSeriesSplit
from sklearn.metrics import mean_squared_error

def forecast_for_id(train_data, test_data, id):
    train_id = train_data.loc[id].reset_index()
    train_id.columns = ['ds', 'y']

    # Define TimeSeriesSplit for cross-validation
    tscv = TimeSeriesSplit(n_splits=5) ## try another cross validation 

    # Perform auto ARIMA model selection with cross-validation
    model = auto_arima(train_id['y'], seasonal=False, trace=True, error_action='ignore', suppress_warnings=True, scoring='mse', cv=tscv)

    # Forecast for the next 2 dates in test data
    future_dates = test_data.iloc[:2]
    future_dates.columns = ['ds']
    forecast = model.predict(n_periods=2)  # Forecast 2 steps ahead

    # Convert forecast to DataFrame
    forecast_df = pd.DataFrame({'ds': future_dates['ds'].values, 'yhat': forecast})

    return forecast_df

# now we loop over unique IDs in train data and forecast
forecasts = []
for id in train_grouped.index.levels[0]:
    forecasts.append(forecast_for_id(train_grouped, test, id))

all_forecasts = pd.concat(forecasts)  # concatenate forecasts for all IDs

test['target'] = all_forecasts['yhat'].values  # add predicted values to test data
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=13135.007, Time=2.04 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=13802.624, Time=0.09 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=13490.149, Time=0.09 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=13145.041, Time=0.14 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=13800.630, Time=0.03 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=13129.066, Time=2.34 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=13132.403, Time=0.51 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=13131.879, Time=0.34 sec
#  ARIMA(1,1,3)(0,0,0)[0] intercept   : AIC=13135.675, Time=1.73 sec
#  ARIMA(0,1,3)(0,0,0)[0] intercept   : AIC=13134.206, Time=0.88 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=13133.457, Time=0.45 sec
#  ARIMA(2,1,3)(0,0,0)[0] intercept   : AIC=inf, Time=3.67 sec
#  ARIMA(1,1,2)(0,0,0)[0]             : AIC=13127.704, Time=0.58 sec
#  ARIMA(0,1,2)(0,0,0)[0]             : AIC=13130.667, Time=0.14 sec
#  ARIMA(1,1,1)(0,0,0)[0]             : AIC=13130.155, Time=0.16 sec
#  ARIMA(2,1,2)(0,0,0)[0]             : AIC=13133.275, Time=0.59 sec
#  ARIMA(1,1,3)(0,0,0)[0]             : AIC=13133.933, Time=0.95 sec
#  ARIMA(0,1,1)(0,0,0)[0]             : AIC=13143.249, Time=0.16 sec
#  ARIMA(0,1,3)(0,0,0)[0]             : AIC=13132.478, Time=0.54 sec
#  ARIMA(2,1,1)(0,0,0)[0]             : AIC=13131.747, Time=0.28 sec
#  ARIMA(2,1,3)(0,0,0)[0]             : AIC=inf, Time=2.71 sec
#
# Best model:  ARIMA(1,1,2)(0,0,0)[0]
# Total fit time: 18.428 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=6917.228, Time=1.21 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=7707.989, Time=0.03 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=7305.102, Time=0.08 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=6924.356, Time=0.16 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=7705.991, Time=0.03 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=6928.051, Time=0.49 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=6919.451, Time=0.64 sec
#  ARIMA(3,1,2)(0,0,0)[0] intercept   : AIC=6904.935, Time=0.91 sec
#  ARIMA(3,1,1)(0,0,0)[0] intercept   : AIC=6909.089, Time=0.50 sec
#  ARIMA(4,1,2)(0,0,0)[0] intercept   : AIC=6901.803, Time=4.35 sec
#  ARIMA(4,1,1)(0,0,0)[0] intercept   : AIC=6901.485, Time=1.27 sec
#  ARIMA(4,1,0)(0,0,0)[0] intercept   : AIC=7100.702, Time=0.64 sec
#  ARIMA(5,1,1)(0,0,0)[0] intercept   : AIC=6896.457, Time=1.63 sec
#  ARIMA(5,1,0)(0,0,0)[0] intercept   : AIC=7004.828, Time=0.98 sec
#  ARIMA(5,1,2)(0,0,0)[0] intercept   : AIC=6898.430, Time=3.04 sec
#  ARIMA(5,1,1)(0,0,0)[0]             : AIC=6894.631, Time=1.05 sec
#  ARIMA(4,1,1)(0,0,0)[0]             : AIC=6899.911, Time=0.70 sec
#  ARIMA(5,1,0)(0,0,0)[0]             : AIC=7002.830, Time=0.47 sec
#  ARIMA(5,1,2)(0,0,0)[0]             : AIC=6896.615, Time=2.02 sec
#  ARIMA(4,1,0)(0,0,0)[0]             : AIC=7098.702, Time=0.37 sec
#  ARIMA(4,1,2)(0,0,0)[0]             : AIC=6900.131, Time=1.89 sec
#
# Best model:  ARIMA(5,1,1)(0,0,0)[0]
# Total fit time: 22.491 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=7241.728, Time=1.59 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=8242.220, Time=0.08 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=7631.995, Time=0.10 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=7274.526, Time=0.18 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=8240.220, Time=0.03 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=7241.239, Time=0.90 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=7250.477, Time=0.52 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=7245.785, Time=0.35 sec
#  ARIMA(1,1,3)(0,0,0)[0] intercept   : AIC=7240.746, Time=1.87 sec
#  ARIMA(0,1,3)(0,0,0)[0] intercept   : AIC=7241.372, Time=1.54 sec
#  ARIMA(2,1,3)(0,0,0)[0] intercept   : AIC=7240.931, Time=2.91 sec
#  ARIMA(1,1,4)(0,0,0)[0] intercept   : AIC=7234.974, Time=2.38 sec
#  ARIMA(0,1,4)(0,0,0)[0] intercept   : AIC=7237.008, Time=1.55 sec
#  ARIMA(2,1,4)(0,0,0)[0] intercept   : AIC=7212.881, Time=3.69 sec
#  ARIMA(3,1,4)(0,0,0)[0] intercept   : AIC=7173.767, Time=4.36 sec
#  ARIMA(3,1,3)(0,0,0)[0] intercept   : AIC=7177.797, Time=4.24 sec
#  ARIMA(4,1,4)(0,0,0)[0] intercept   : AIC=7177.218, Time=5.25 sec
#  ARIMA(3,1,5)(0,0,0)[0] intercept   : AIC=7216.070, Time=5.22 sec
#  ARIMA(2,1,5)(0,0,0)[0] intercept   : AIC=7191.339, Time=5.65 sec
#  ARIMA(4,1,3)(0,0,0)[0] intercept   : AIC=7176.768, Time=4.44 sec
#  ARIMA(4,1,5)(0,0,0)[0] intercept   : AIC=7178.920, Time=7.07 sec
#  ARIMA(3,1,4)(0,0,0)[0]             : AIC=7169.778, Time=3.63 sec
#  ARIMA(2,1,4)(0,0,0)[0]             : AIC=7210.923, Time=1.89 sec
#  ARIMA(3,1,3)(0,0,0)[0]             : AIC=7170.649, Time=2.83 sec
#  ARIMA(4,1,4)(0,0,0)[0]             : AIC=7174.298, Time=3.58 sec
#  ARIMA(3,1,5)(0,0,0)[0]             : AIC=7214.120, Time=3.70 sec
#  ARIMA(2,1,3)(0,0,0)[0]             : AIC=7238.962, Time=1.24 sec
#  ARIMA(2,1,5)(0,0,0)[0]             : AIC=7180.255, Time=3.67 sec
#  ARIMA(4,1,3)(0,0,0)[0]             : AIC=7168.902, Time=3.24 sec
#  ARIMA(4,1,2)(0,0,0)[0]             : AIC=7230.686, Time=2.34 sec
#  ARIMA(5,1,3)(0,0,0)[0]             : AIC=7171.880, Time=4.16 sec
#  ARIMA(3,1,2)(0,0,0)[0]             : AIC=7242.114, Time=0.58 sec
#  ARIMA(5,1,2)(0,0,0)[0]             : AIC=7232.042, Time=1.62 sec
#  ARIMA(5,1,4)(0,0,0)[0]             : AIC=inf, Time=4.17 sec
#
# Best model:  ARIMA(4,1,3)(0,0,0)[0]
# Total fit time: 90.614 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=9743.180, Time=1.54 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=10119.149, Time=0.08 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=9872.711, Time=0.09 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=9745.944, Time=0.13 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=10117.150, Time=0.03 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=9749.843, Time=0.42 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=9744.914, Time=0.42 sec
#  ARIMA(3,1,2)(0,0,0)[0] intercept   : AIC=9743.164, Time=0.79 sec
#  ARIMA(3,1,1)(0,0,0)[0] intercept   : AIC=9744.360, Time=0.51 sec
#  ARIMA(4,1,2)(0,0,0)[0] intercept   : AIC=9743.405, Time=2.34 sec
#  ARIMA(3,1,3)(0,0,0)[0] intercept   : AIC=9735.887, Time=4.19 sec
#  ARIMA(2,1,3)(0,0,0)[0] intercept   : AIC=9740.010, Time=2.28 sec
#  ARIMA(4,1,3)(0,0,0)[0] intercept   : AIC=9734.470, Time=4.47 sec
#  ARIMA(5,1,3)(0,0,0)[0] intercept   : AIC=9693.286, Time=5.93 sec
#  ARIMA(5,1,2)(0,0,0)[0] intercept   : AIC=9690.790, Time=5.27 sec
#  ARIMA(5,1,1)(0,0,0)[0] intercept   : AIC=9741.093, Time=1.36 sec
#  ARIMA(4,1,1)(0,0,0)[0] intercept   : AIC=9742.071, Time=1.70 sec
#  ARIMA(5,1,2)(0,0,0)[0]             : AIC=9688.145, Time=3.44 sec
#  ARIMA(4,1,2)(0,0,0)[0]             : AIC=9741.406, Time=1.48 sec
#  ARIMA(5,1,1)(0,0,0)[0]             : AIC=9739.094, Time=1.06 sec
#  ARIMA(5,1,3)(0,0,0)[0]             : AIC=9691.652, Time=3.42 sec
#  ARIMA(4,1,1)(0,0,0)[0]             : AIC=9740.071, Time=0.97 sec
#  ARIMA(4,1,3)(0,0,0)[0]             : AIC=9732.454, Time=2.77 sec
#
# Best model:  ARIMA(5,1,2)(0,0,0)[0]
# Total fit time: 44.731 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=5450.325, Time=1.27 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=6045.511, Time=0.06 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=5796.793, Time=0.10 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=5447.384, Time=0.13 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=6043.511, Time=0.03 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=5447.761, Time=0.24 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=5447.648, Time=0.51 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=5449.513, Time=1.20 sec
#  ARIMA(0,1,1)(0,0,0)[0]             : AIC=5445.415, Time=0.06 sec
#  ARIMA(1,1,1)(0,0,0)[0]             : AIC=5445.791, Time=0.08 sec
#  ARIMA(0,1,2)(0,0,0)[0]             : AIC=5445.678, Time=0.08 sec
#  ARIMA(1,1,0)(0,0,0)[0]             : AIC=5794.794, Time=0.11 sec
#  ARIMA(1,1,2)(0,0,0)[0]             : AIC=5447.544, Time=0.62 sec
#
# Best model:  ARIMA(0,1,1)(0,0,0)[0]
# Total fit time: 4.492 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=2888.674, Time=0.48 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=3154.434, Time=0.04 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=2952.091, Time=0.09 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=2900.340, Time=0.06 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=3152.439, Time=0.01 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=2889.823, Time=0.25 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=2886.924, Time=0.29 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=2894.669, Time=0.09 sec
#  ARIMA(2,1,0)(0,0,0)[0] intercept   : AIC=2931.416, Time=0.06 sec
#  ARIMA(3,1,1)(0,0,0)[0] intercept   : AIC=2888.756, Time=0.36 sec
#  ARIMA(3,1,0)(0,0,0)[0] intercept   : AIC=2912.562, Time=0.22 sec
#  ARIMA(3,1,2)(0,0,0)[0] intercept   : AIC=2890.164, Time=0.78 sec
#  ARIMA(2,1,1)(0,0,0)[0]             : AIC=2885.000, Time=0.17 sec
#  ARIMA(1,1,1)(0,0,0)[0]             : AIC=2892.716, Time=0.05 sec
#  ARIMA(2,1,0)(0,0,0)[0]             : AIC=2929.428, Time=0.04 sec
#  ARIMA(3,1,1)(0,0,0)[0]             : AIC=2886.829, Time=0.25 sec
#  ARIMA(2,1,2)(0,0,0)[0]             : AIC=2886.747, Time=0.31 sec
#  ARIMA(1,1,0)(0,0,0)[0]             : AIC=2950.100, Time=0.06 sec
#  ARIMA(1,1,2)(0,0,0)[0]             : AIC=2887.878, Time=0.17 sec
#  ARIMA(3,1,0)(0,0,0)[0]             : AIC=2910.579, Time=0.05 sec
#  ARIMA(3,1,2)(0,0,0)[0]             : AIC=2888.240, Time=0.23 sec
#
# Best model:  ARIMA(2,1,1)(0,0,0)[0]
# Total fit time: 4.087 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=11779.358, Time=0.68 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=12616.313, Time=0.03 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=12190.909, Time=0.08 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=11775.742, Time=0.15 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=12614.313, Time=0.03 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=11776.907, Time=0.25 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=11776.958, Time=0.23 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=11777.884, Time=1.12 sec
#  ARIMA(0,1,1)(0,0,0)[0]             : AIC=11773.777, Time=0.10 sec
#  ARIMA(1,1,1)(0,0,0)[0]             : AIC=11774.941, Time=0.22 sec
#  ARIMA(0,1,2)(0,0,0)[0]             : AIC=11774.992, Time=0.19 sec
#  ARIMA(1,1,0)(0,0,0)[0]             : AIC=12188.912, Time=0.09 sec
#  ARIMA(1,1,2)(0,0,0)[0]             : AIC=11775.918, Time=0.30 sec
#
# Best model:  ARIMA(0,1,1)(0,0,0)[0]
# Total fit time: 3.501 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=6984.598, Time=0.32 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=7800.135, Time=0.03 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=7431.798, Time=0.08 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=6979.066, Time=0.15 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=7798.136, Time=0.03 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=6980.608, Time=0.25 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=6980.589, Time=0.46 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=6982.418, Time=1.51 sec
#  ARIMA(0,1,1)(0,0,0)[0]             : AIC=6977.066, Time=0.13 sec
#  ARIMA(1,1,1)(0,0,0)[0]             : AIC=6978.608, Time=0.11 sec
#  ARIMA(0,1,2)(0,0,0)[0]             : AIC=6978.589, Time=0.24 sec
#  ARIMA(1,1,0)(0,0,0)[0]             : AIC=7429.803, Time=0.12 sec
#  ARIMA(1,1,2)(0,0,0)[0]             : AIC=6980.419, Time=0.38 sec
#
# Best model:  ARIMA(0,1,1)(0,0,0)[0]
# Total fit time: 3.811 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=6849.351, Time=0.49 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=7278.460, Time=0.03 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=7138.582, Time=0.09 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=6926.985, Time=0.10 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=7276.466, Time=0.03 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=6855.666, Time=0.38 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=6854.965, Time=0.27 sec
#  ARIMA(3,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=1.43 sec
#  ARIMA(2,1,3)(0,0,0)[0] intercept   : AIC=6660.235, Time=3.51 sec
#  ARIMA(1,1,3)(0,0,0)[0] intercept   : AIC=6856.494, Time=1.41 sec
#  ARIMA(3,1,3)(0,0,0)[0] intercept   : AIC=6658.726, Time=3.47 sec
#  ARIMA(4,1,3)(0,0,0)[0] intercept   : AIC=6660.996, Time=3.93 sec
#  ARIMA(3,1,4)(0,0,0)[0] intercept   : AIC=6651.661, Time=4.69 sec
#  ARIMA(2,1,4)(0,0,0)[0] intercept   : AIC=6658.587, Time=3.90 sec
#  ARIMA(4,1,4)(0,0,0)[0] intercept   : AIC=6652.979, Time=5.37 sec
#  ARIMA(3,1,5)(0,0,0)[0] intercept   : AIC=6652.988, Time=5.13 sec
#  ARIMA(2,1,5)(0,0,0)[0] intercept   : AIC=6660.556, Time=4.60 sec
#  ARIMA(4,1,5)(0,0,0)[0] intercept   : AIC=6659.210, Time=5.53 sec
#  ARIMA(3,1,4)(0,0,0)[0]             : AIC=6649.674, Time=3.04 sec
#  ARIMA(2,1,4)(0,0,0)[0]             : AIC=6656.780, Time=2.75 sec
#  ARIMA(3,1,3)(0,0,0)[0]             : AIC=6656.699, Time=2.44 sec
#  ARIMA(4,1,4)(0,0,0)[0]             : AIC=6650.923, Time=2.90 sec
#  ARIMA(3,1,5)(0,0,0)[0]             : AIC=6650.733, Time=3.67 sec
#  ARIMA(2,1,3)(0,0,0)[0]             : AIC=6658.340, Time=3.33 sec
#  ARIMA(2,1,5)(0,0,0)[0]             : AIC=6658.661, Time=3.25 sec
#  ARIMA(4,1,3)(0,0,0)[0]             : AIC=6659.579, Time=2.74 sec
#  ARIMA(4,1,5)(0,0,0)[0]             : AIC=6656.789, Time=3.67 sec
#
# Best model:  ARIMA(3,1,4)(0,0,0)[0]
# Total fit time: 72.171 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=9696.143, Time=0.62 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=9957.191, Time=0.03 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=9836.035, Time=0.12 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=9739.666, Time=0.11 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=9955.241, Time=0.03 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=9694.134, Time=0.30 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=9697.840, Time=0.20 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=9692.143, Time=0.18 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=9694.131, Time=0.41 sec
#  ARIMA(2,1,0)(0,0,0)[0] intercept   : AIC=9788.010, Time=0.25 sec
#  ARIMA(1,1,1)(0,0,0)[0]             : AIC=9690.393, Time=0.10 sec
#  ARIMA(0,1,1)(0,0,0)[0]             : AIC=9737.826, Time=0.06 sec
#  ARIMA(1,1,0)(0,0,0)[0]             : AIC=9834.112, Time=0.07 sec
#  ARIMA(2,1,1)(0,0,0)[0]             : AIC=9692.384, Time=0.26 sec
#  ARIMA(1,1,2)(0,0,0)[0]             : AIC=9692.386, Time=0.15 sec
#  ARIMA(0,1,2)(0,0,0)[0]             : AIC=9696.052, Time=0.09 sec
#  ARIMA(2,1,0)(0,0,0)[0]             : AIC=9786.107, Time=0.10 sec
#  ARIMA(2,1,2)(0,0,0)[0]             : AIC=9694.393, Time=0.30 sec
#
# Best model:  ARIMA(1,1,1)(0,0,0)[0]
# Total fit time: 3.400 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=92.050, Time=0.23 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=98.641, Time=0.02 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=94.824, Time=0.03 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=97.154, Time=0.03 sec
#  ARIMA(1,0,2)(0,0,0)[0]             : AIC=91.105, Time=0.09 sec
#  ARIMA(0,0,2)(0,0,0)[0]             : AIC=96.747, Time=0.02 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=89.345, Time=0.04 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=91.153, Time=0.04 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=93.598, Time=0.02 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=87.904, Time=0.10 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=85.956, Time=0.02 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=83.957, Time=0.12 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=85.956, Time=0.02 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[0] intercept
# Total fit time: 0.783 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=4754.922, Time=0.45 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=5043.880, Time=0.03 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=4898.363, Time=0.10 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=4752.096, Time=0.08 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=5041.880, Time=0.02 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=4753.037, Time=0.15 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=4753.172, Time=0.15 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=4755.054, Time=0.33 sec
#  ARIMA(0,1,1)(0,0,0)[0]             : AIC=4750.152, Time=0.07 sec
#  ARIMA(1,1,1)(0,0,0)[0]             : AIC=4751.078, Time=0.12 sec
#  ARIMA(0,1,2)(0,0,0)[0]             : AIC=4751.216, Time=0.10 sec
#  ARIMA(1,1,0)(0,0,0)[0]             : AIC=4896.363, Time=0.06 sec
#  ARIMA(1,1,2)(0,0,0)[0]             : AIC=4753.112, Time=0.21 sec
#
# Best model:  ARIMA(0,1,1)(0,0,0)[0]
# Total fit time: 1.880 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=2040.073, Time=0.24 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=2122.673, Time=0.02 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=2081.616, Time=0.06 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=2050.268, Time=0.07 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=2120.675, Time=0.03 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=2038.166, Time=0.18 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=2048.312, Time=0.09 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=2049.756, Time=0.11 sec
#  ARIMA(1,1,3)(0,0,0)[0] intercept   : AIC=2040.056, Time=0.21 sec
#  ARIMA(0,1,3)(0,0,0)[0] intercept   : AIC=2045.117, Time=0.10 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=2044.991, Time=0.15 sec
#  ARIMA(2,1,3)(0,0,0)[0] intercept   : AIC=2042.019, Time=1.33 sec
#  ARIMA(1,1,2)(0,0,0)[0]             : AIC=2036.171, Time=0.15 sec
#  ARIMA(0,1,2)(0,0,0)[0]             : AIC=2046.318, Time=0.03 sec
#  ARIMA(1,1,1)(0,0,0)[0]             : AIC=2047.762, Time=0.05 sec
#  ARIMA(2,1,2)(0,0,0)[0]             : AIC=2038.078, Time=0.26 sec
#  ARIMA(1,1,3)(0,0,0)[0]             : AIC=2038.062, Time=0.23 sec
#  ARIMA(0,1,1)(0,0,0)[0]             : AIC=2048.273, Time=0.06 sec
#  ARIMA(0,1,3)(0,0,0)[0]             : AIC=2043.123, Time=0.11 sec
#  ARIMA(2,1,1)(0,0,0)[0]             : AIC=2042.996, Time=0.15 sec
#  ARIMA(2,1,3)(0,0,0)[0]             : AIC=2040.024, Time=0.78 sec
#
# Best model:  ARIMA(1,1,2)(0,0,0)[0]
# Total fit time: 4.415 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=5759.108, Time=0.56 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=6250.218, Time=0.03 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=6008.706, Time=0.07 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=5759.490, Time=0.10 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=6248.220, Time=0.03 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=5758.278, Time=0.27 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=5756.492, Time=0.13 sec
#  ARIMA(0,1,3)(0,0,0)[0] intercept   : AIC=5757.993, Time=0.57 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=5756.312, Time=0.25 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=5758.237, Time=0.21 sec
#  ARIMA(2,1,0)(0,0,0)[0] intercept   : AIC=5928.850, Time=0.12 sec
#  ARIMA(1,1,1)(0,0,0)[0]             : AIC=5754.322, Time=0.07 sec
#  ARIMA(0,1,1)(0,0,0)[0]             : AIC=5757.493, Time=0.05 sec
#  ARIMA(1,1,0)(0,0,0)[0]             : AIC=6006.710, Time=0.03 sec
#  ARIMA(2,1,1)(0,0,0)[0]             : AIC=5756.247, Time=0.11 sec
#  ARIMA(1,1,2)(0,0,0)[0]             : AIC=5756.288, Time=0.44 sec
#  ARIMA(0,1,2)(0,0,0)[0]             : AIC=5754.500, Time=0.17 sec
#  ARIMA(2,1,0)(0,0,0)[0]             : AIC=5926.857, Time=0.13 sec
#  ARIMA(2,1,2)(0,0,0)[0]             : AIC=5757.119, Time=0.72 sec
#
# Best model:  ARIMA(1,1,1)(0,0,0)[0]
# Total fit time: 4.050 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=11347.434, Time=0.86 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=12023.221, Time=0.07 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=11750.699, Time=0.14 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=11348.870, Time=0.22 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=12021.222, Time=0.03 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=11345.857, Time=1.08 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=11343.868, Time=0.57 sec
#  ARIMA(0,1,3)(0,0,0)[0] intercept   : AIC=11345.857, Time=0.90 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=11343.959, Time=0.36 sec
#  ARIMA(1,1,3)(0,0,0)[0] intercept   : AIC=11347.840, Time=1.18 sec
#  ARIMA(0,1,2)(0,0,0)[0]             : AIC=11342.235, Time=0.31 sec
#  ARIMA(0,1,1)(0,0,0)[0]             : AIC=11347.161, Time=0.11 sec
#  ARIMA(1,1,2)(0,0,0)[0]             : AIC=11344.220, Time=0.63 sec
#  ARIMA(0,1,3)(0,0,0)[0]             : AIC=11344.220, Time=0.90 sec
#  ARIMA(1,1,1)(0,0,0)[0]             : AIC=11342.333, Time=0.21 sec
#  ARIMA(1,1,3)(0,0,0)[0]             : AIC=11346.203, Time=0.65 sec
#
# Best model:  ARIMA(0,1,2)(0,0,0)[0]
# Total fit time: 8.238 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=415.453, Time=0.22 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=475.312, Time=0.01 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=426.843, Time=0.03 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=410.613, Time=0.04 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=473.312, Time=0.01 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=412.046, Time=0.06 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=412.132, Time=0.05 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=413.551, Time=0.09 sec
#  ARIMA(0,1,1)(0,0,0)[0]             : AIC=408.661, Time=0.02 sec
#  ARIMA(1,1,1)(0,0,0)[0]             : AIC=410.080, Time=0.03 sec
#  ARIMA(0,1,2)(0,0,0)[0]             : AIC=410.168, Time=0.03 sec
#  ARIMA(1,1,0)(0,0,0)[0]             : AIC=424.846, Time=0.02 sec
#  ARIMA(1,1,2)(0,0,0)[0]             : AIC=411.591, Time=0.06 sec
#
# Best model:  ARIMA(0,1,1)(0,0,0)[0]
# Total fit time: 0.673 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=5610.322, Time=0.34 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=6162.778, Time=0.03 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=5893.168, Time=0.08 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=5606.190, Time=0.13 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=6160.778, Time=0.03 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=5608.132, Time=0.19 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=5608.127, Time=0.14 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=5608.847, Time=0.48 sec
#  ARIMA(0,1,1)(0,0,0)[0]             : AIC=5604.190, Time=0.05 sec
#  ARIMA(1,1,1)(0,0,0)[0]             : AIC=5606.132, Time=0.06 sec
#  ARIMA(0,1,2)(0,0,0)[0]             : AIC=5606.127, Time=0.06 sec
#  ARIMA(1,1,0)(0,0,0)[0]             : AIC=5891.169, Time=0.04 sec
#  ARIMA(1,1,2)(0,0,0)[0]             : AIC=5606.847, Time=0.25 sec
#
# Best model:  ARIMA(0,1,1)(0,0,0)[0]
# Total fit time: 1.899 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=10913.996, Time=0.61 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=11109.412, Time=0.03 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=11098.582, Time=0.05 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=11094.039, Time=0.06 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=11107.412, Time=0.02 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=10936.640, Time=0.33 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=10933.245, Time=0.37 sec
#  ARIMA(3,1,2)(0,0,0)[0] intercept   : AIC=10913.406, Time=0.97 sec
#  ARIMA(3,1,1)(0,0,0)[0] intercept   : AIC=10921.038, Time=0.48 sec
#  ARIMA(4,1,2)(0,0,0)[0] intercept   : AIC=10924.503, Time=2.62 sec
#  ARIMA(3,1,3)(0,0,0)[0] intercept   : AIC=10948.618, Time=3.00 sec
#  ARIMA(2,1,3)(0,0,0)[0] intercept   : AIC=10913.253, Time=2.81 sec
#  ARIMA(1,1,3)(0,0,0)[0] intercept   : AIC=10928.902, Time=1.36 sec
#  ARIMA(2,1,4)(0,0,0)[0] intercept   : AIC=10932.352, Time=2.77 sec
#  ARIMA(1,1,4)(0,0,0)[0] intercept   : AIC=10928.660, Time=2.06 sec
#  ARIMA(3,1,4)(0,0,0)[0] intercept   : AIC=10915.815, Time=3.71 sec
#  ARIMA(2,1,3)(0,0,0)[0]             : AIC=10911.282, Time=1.63 sec
#  ARIMA(1,1,3)(0,0,0)[0]             : AIC=10926.936, Time=0.73 sec
#  ARIMA(2,1,2)(0,0,0)[0]             : AIC=10912.024, Time=0.46 sec
#  ARIMA(3,1,3)(0,0,0)[0]             : AIC=10946.553, Time=2.26 sec
#  ARIMA(2,1,4)(0,0,0)[0]             : AIC=10930.387, Time=2.28 sec
#  ARIMA(1,1,2)(0,0,0)[0]             : AIC=10934.674, Time=0.58 sec
#  ARIMA(1,1,4)(0,0,0)[0]             : AIC=10926.695, Time=1.17 sec
#  ARIMA(3,1,2)(0,0,0)[0]             : AIC=10911.434, Time=1.44 sec
#  ARIMA(3,1,4)(0,0,0)[0]             : AIC=10913.845, Time=2.34 sec
#
# Best model:  ARIMA(2,1,3)(0,0,0)[0]
# Total fit time: 34.171 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=2327.382, Time=0.42 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=2445.058, Time=0.03 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=2381.260, Time=0.09 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=2332.235, Time=0.05 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=2443.075, Time=0.02 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=2322.085, Time=0.57 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=2326.166, Time=0.07 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=2324.561, Time=0.09 sec
#  ARIMA(1,1,3)(0,0,0)[0] intercept   : AIC=2322.095, Time=1.12 sec
#  ARIMA(0,1,3)(0,0,0)[0] intercept   : AIC=2326.074, Time=0.28 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=2323.536, Time=0.22 sec
#  ARIMA(2,1,3)(0,0,0)[0] intercept   : AIC=2278.967, Time=1.32 sec
#  ARIMA(3,1,3)(0,0,0)[0] intercept   : AIC=2304.499, Time=1.57 sec
#  ARIMA(2,1,4)(0,0,0)[0] intercept   : AIC=2303.120, Time=1.12 sec
#  ARIMA(1,1,4)(0,0,0)[0] intercept   : AIC=2317.984, Time=0.55 sec
#  ARIMA(3,1,2)(0,0,0)[0] intercept   : AIC=2322.221, Time=0.37 sec
#  ARIMA(3,1,4)(0,0,0)[0] intercept   : AIC=2301.657, Time=0.77 sec
#  ARIMA(2,1,3)(0,0,0)[0]             : AIC=2277.102, Time=0.93 sec
#  ARIMA(1,1,3)(0,0,0)[0]             : AIC=2321.341, Time=0.44 sec
#  ARIMA(2,1,2)(0,0,0)[0]             : AIC=2325.612, Time=0.18 sec
#  ARIMA(3,1,3)(0,0,0)[0]             : AIC=2302.812, Time=1.18 sec
#  ARIMA(2,1,4)(0,0,0)[0]             : AIC=2301.426, Time=0.74 sec
#  ARIMA(1,1,2)(0,0,0)[0]             : AIC=2321.292, Time=0.23 sec
#  ARIMA(1,1,4)(0,0,0)[0]             : AIC=2317.004, Time=0.33 sec
#  ARIMA(3,1,2)(0,0,0)[0]             : AIC=2321.288, Time=0.24 sec
#  ARIMA(3,1,4)(0,0,0)[0]             : AIC=2299.891, Time=0.51 sec
#
# Best model:  ARIMA(2,1,3)(0,0,0)[0]
# Total fit time: 13.471 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=5776.670, Time=0.66 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=6172.965, Time=0.06 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=5957.958, Time=0.10 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=5778.263, Time=0.09 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=6170.965, Time=0.02 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=5775.155, Time=0.42 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=5774.838, Time=0.15 sec
#  ARIMA(0,1,3)(0,0,0)[0] intercept   : AIC=5774.674, Time=0.56 sec
#  ARIMA(1,1,3)(0,0,0)[0] intercept   : AIC=5776.417, Time=1.02 sec
#  ARIMA(0,1,4)(0,0,0)[0] intercept   : AIC=5775.942, Time=0.68 sec
#  ARIMA(1,1,4)(0,0,0)[0] intercept   : AIC=5777.904, Time=1.13 sec
#  ARIMA(0,1,3)(0,0,0)[0]             : AIC=5772.763, Time=0.24 sec
#  ARIMA(0,1,2)(0,0,0)[0]             : AIC=5772.915, Time=0.14 sec
#  ARIMA(1,1,3)(0,0,0)[0]             : AIC=5774.510, Time=0.56 sec
#  ARIMA(0,1,4)(0,0,0)[0]             : AIC=5774.040, Time=0.41 sec
#  ARIMA(1,1,2)(0,0,0)[0]             : AIC=5773.245, Time=0.25 sec
#  ARIMA(1,1,4)(0,0,0)[0]             : AIC=5776.001, Time=0.83 sec
#
# Best model:  ARIMA(0,1,3)(0,0,0)[0]
# Total fit time: 7.335 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=5838.626, Time=0.24 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=6203.110, Time=0.02 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=5948.327, Time=0.05 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=5834.987, Time=0.10 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=6201.120, Time=0.02 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=5834.664, Time=0.11 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=5836.631, Time=0.19 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=5836.642, Time=0.20 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=5834.642, Time=0.11 sec
#  ARIMA(0,1,3)(0,0,0)[0] intercept   : AIC=5836.642, Time=0.36 sec
#  ARIMA(1,1,3)(0,0,0)[0] intercept   : AIC=5836.958, Time=1.05 sec
#  ARIMA(0,1,2)(0,0,0)[0]             : AIC=5832.678, Time=0.13 sec
#  ARIMA(0,1,1)(0,0,0)[0]             : AIC=5833.018, Time=0.04 sec
#  ARIMA(1,1,2)(0,0,0)[0]             : AIC=5834.678, Time=0.11 sec
#  ARIMA(0,1,3)(0,0,0)[0]             : AIC=5834.678, Time=0.23 sec
#  ARIMA(1,1,1)(0,0,0)[0]             : AIC=5832.699, Time=0.14 sec
#  ARIMA(1,1,3)(0,0,0)[0]             : AIC=5834.993, Time=0.74 sec
#
# Best model:  ARIMA(0,1,2)(0,0,0)[0]
# Total fit time: 3.867 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=7964.213, Time=0.37 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=10307.905, Time=0.02 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=8417.266, Time=0.04 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=9524.225, Time=0.07 sec
#  ARIMA(1,0,2)(0,0,0)[0]             : AIC=7962.253, Time=0.38 sec
#  ARIMA(0,0,2)(0,0,0)[0]             : AIC=9123.045, Time=0.37 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=7970.776, Time=0.26 sec
#  ARIMA(1,0,3)(0,0,0)[0]             : AIC=7964.137, Time=1.40 sec
#  ARIMA(0,0,3)(0,0,0)[0]             : AIC=8925.384, Time=0.51 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=7962.808, Time=0.30 sec
#  ARIMA(2,0,3)(0,0,0)[0]             : AIC=7965.857, Time=0.81 sec
#  ARIMA(1,0,2)(0,0,0)[0] intercept   : AIC=7947.174, Time=1.85 sec
#  ARIMA(0,0,2)(0,0,0)[0] intercept   : AIC=8026.476, Time=0.54 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=7954.139, Time=0.61 sec
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.74 sec
#  ARIMA(1,0,3)(0,0,0)[0] intercept   : AIC=7948.848, Time=2.17 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=8049.572, Time=0.22 sec
#  ARIMA(0,0,3)(0,0,0)[0] intercept   : AIC=8020.792, Time=0.77 sec
#  ARIMA(2,0,1)(0,0,0)[0] intercept   : AIC=7949.440, Time=0.82 sec
#  ARIMA(2,0,3)(0,0,0)[0] intercept   : AIC=inf, Time=2.46 sec
#
# Best model:  ARIMA(1,0,2)(0,0,0)[0] intercept
# Total fit time: 14.736 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=3166.532, Time=0.56 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=3442.057, Time=0.02 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=3287.265, Time=0.05 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=3180.935, Time=0.07 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=3440.073, Time=0.02 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=3165.338, Time=0.68 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=3179.874, Time=0.25 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=3178.073, Time=0.14 sec
#  ARIMA(1,1,3)(0,0,0)[0] intercept   : AIC=3166.542, Time=1.29 sec
#  ARIMA(0,1,3)(0,0,0)[0] intercept   : AIC=3173.851, Time=0.42 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=3168.907, Time=0.31 sec
#  ARIMA(2,1,3)(0,0,0)[0] intercept   : AIC=3184.915, Time=1.36 sec
#  ARIMA(1,1,2)(0,0,0)[0]             : AIC=3163.617, Time=0.27 sec
#  ARIMA(0,1,2)(0,0,0)[0]             : AIC=3178.048, Time=0.06 sec
#  ARIMA(1,1,1)(0,0,0)[0]             : AIC=3176.284, Time=0.07 sec
#  ARIMA(2,1,2)(0,0,0)[0]             : AIC=3164.808, Time=0.25 sec
#  ARIMA(1,1,3)(0,0,0)[0]             : AIC=3164.818, Time=0.55 sec
#  ARIMA(0,1,1)(0,0,0)[0]             : AIC=3179.069, Time=0.09 sec
#  ARIMA(0,1,3)(0,0,0)[0]             : AIC=3172.085, Time=0.22 sec
#  ARIMA(2,1,1)(0,0,0)[0]             : AIC=3167.163, Time=0.18 sec
#  ARIMA(2,1,3)(0,0,0)[0]             : AIC=3183.056, Time=0.88 sec
#
# Best model:  ARIMA(1,1,2)(0,0,0)[0]
# Total fit time: 7.764 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=5961.709, Time=0.93 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=6420.479, Time=0.02 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=6122.603, Time=0.07 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=5986.245, Time=0.08 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=6418.479, Time=0.02 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=5988.659, Time=0.29 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=5973.885, Time=0.29 sec
#  ARIMA(3,1,2)(0,0,0)[0] intercept   : AIC=5976.801, Time=0.82 sec
#  ARIMA(2,1,3)(0,0,0)[0] intercept   : AIC=5970.739, Time=1.64 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=5988.078, Time=0.22 sec
#  ARIMA(1,1,3)(0,0,0)[0] intercept   : AIC=5962.238, Time=1.91 sec
#  ARIMA(3,1,1)(0,0,0)[0] intercept   : AIC=5966.466, Time=0.47 sec
#  ARIMA(3,1,3)(0,0,0)[0] intercept   : AIC=5974.567, Time=1.81 sec
#  ARIMA(2,1,2)(0,0,0)[0]             : AIC=5961.819, Time=0.56 sec
#
# Best model:  ARIMA(2,1,2)(0,0,0)[0] intercept
# Total fit time: 9.147 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=1304.271, Time=0.16 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=1472.914, Time=0.01 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=1344.704, Time=0.03 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=1311.625, Time=0.05 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=1470.920, Time=0.01 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=1303.229, Time=0.07 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=1307.760, Time=0.07 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=1305.992, Time=0.06 sec
#  ARIMA(1,1,3)(0,0,0)[0] intercept   : AIC=1303.448, Time=0.38 sec
#  ARIMA(0,1,3)(0,0,0)[0] intercept   : AIC=1306.100, Time=0.19 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=1303.938, Time=0.18 sec
#  ARIMA(2,1,3)(0,0,0)[0] intercept   : AIC=1303.857, Time=0.58 sec
#  ARIMA(1,1,2)(0,0,0)[0]             : AIC=1301.232, Time=0.14 sec
#  ARIMA(0,1,2)(0,0,0)[0]             : AIC=1305.764, Time=0.07 sec
#  ARIMA(1,1,1)(0,0,0)[0]             : AIC=1303.997, Time=0.07 sec
#  ARIMA(2,1,2)(0,0,0)[0]             : AIC=1302.272, Time=0.14 sec
#  ARIMA(1,1,3)(0,0,0)[0]             : AIC=1301.448, Time=0.15 sec
#  ARIMA(0,1,1)(0,0,0)[0]             : AIC=1309.625, Time=0.05 sec
#  ARIMA(0,1,3)(0,0,0)[0]             : AIC=1304.100, Time=0.17 sec
#  ARIMA(2,1,1)(0,0,0)[0]             : AIC=1301.938, Time=0.18 sec
#  ARIMA(2,1,3)(0,0,0)[0]             : AIC=1301.858, Time=0.49 sec
#
# Best model:  ARIMA(1,1,2)(0,0,0)[0]
# Total fit time: 3.287 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=7211.240, Time=0.86 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=7424.571, Time=0.12 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=7331.947, Time=0.09 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=7246.814, Time=0.10 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=7422.576, Time=0.02 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=7209.747, Time=0.28 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=7210.361, Time=0.14 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=7208.844, Time=0.18 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=7208.554, Time=0.27 sec
#  ARIMA(2,1,0)(0,0,0)[0] intercept   : AIC=7298.662, Time=0.14 sec
#  ARIMA(3,1,1)(0,0,0)[0] intercept   : AIC=7190.880, Time=0.27 sec
#  ARIMA(3,1,0)(0,0,0)[0] intercept   : AIC=7237.702, Time=0.18 sec
#  ARIMA(4,1,1)(0,0,0)[0] intercept   : AIC=7188.998, Time=0.92 sec
#  ARIMA(4,1,0)(0,0,0)[0] intercept   : AIC=7215.835, Time=0.77 sec
#  ARIMA(5,1,1)(0,0,0)[0] intercept   : AIC=7170.774, Time=1.12 sec
#  ARIMA(5,1,0)(0,0,0)[0] intercept   : AIC=7176.335, Time=0.93 sec
#  ARIMA(5,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=2.57 sec
#  ARIMA(4,1,2)(0,0,0)[0] intercept   : AIC=7194.880, Time=1.52 sec
#  ARIMA(5,1,1)(0,0,0)[0]             : AIC=7168.794, Time=0.85 sec
#  ARIMA(4,1,1)(0,0,0)[0]             : AIC=7187.017, Time=0.54 sec
#  ARIMA(5,1,0)(0,0,0)[0]             : AIC=7174.352, Time=0.42 sec
#  ARIMA(5,1,2)(0,0,0)[0]             : AIC=7190.302, Time=3.64 sec
#  ARIMA(4,1,0)(0,0,0)[0]             : AIC=7213.848, Time=0.37 sec
#  ARIMA(4,1,2)(0,0,0)[0]             : AIC=7192.899, Time=0.99 sec
#
# Best model:  ARIMA(5,1,1)(0,0,0)[0]
# Total fit time: 17.306 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=4320.124, Time=0.44 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=4652.310, Time=0.02 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=4471.241, Time=0.06 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=4316.543, Time=0.07 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=4650.310, Time=0.02 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=4318.313, Time=0.11 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=4318.308, Time=0.09 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=4318.144, Time=0.39 sec
#  ARIMA(0,1,1)(0,0,0)[0]             : AIC=4314.674, Time=0.08 sec
#  ARIMA(1,1,1)(0,0,0)[0]             : AIC=4316.456, Time=0.08 sec
#  ARIMA(0,1,2)(0,0,0)[0]             : AIC=4316.452, Time=0.11 sec
#  ARIMA(1,1,0)(0,0,0)[0]             : AIC=4469.241, Time=0.08 sec
#  ARIMA(1,1,2)(0,0,0)[0]             : AIC=4316.280, Time=0.39 sec
#
# Best model:  ARIMA(0,1,1)(0,0,0)[0]
# Total fit time: 1.959 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=4495.573, Time=1.41 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=4897.828, Time=0.07 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=4758.920, Time=0.09 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=4521.160, Time=0.12 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=4895.838, Time=0.02 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=4493.016, Time=0.32 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=4491.401, Time=0.20 sec
#  ARIMA(0,1,3)(0,0,0)[0] intercept   : AIC=4492.785, Time=1.04 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=4491.715, Time=0.25 sec
#  ARIMA(1,1,3)(0,0,0)[0] intercept   : AIC=4494.549, Time=0.69 sec
#  ARIMA(0,1,2)(0,0,0)[0]             : AIC=4489.769, Time=0.20 sec
#  ARIMA(0,1,1)(0,0,0)[0]             : AIC=4519.443, Time=0.13 sec
#  ARIMA(1,1,2)(0,0,0)[0]             : AIC=4491.397, Time=0.32 sec
#  ARIMA(0,1,3)(0,0,0)[0]             : AIC=4491.171, Time=0.34 sec
#  ARIMA(1,1,1)(0,0,0)[0]             : AIC=4490.110, Time=0.15 sec
#  ARIMA(1,1,3)(0,0,0)[0]             : AIC=4492.930, Time=0.33 sec
#
# Best model:  ARIMA(0,1,2)(0,0,0)[0]
# Total fit time: 5.699 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=5494.372, Time=0.56 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=5895.733, Time=0.06 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=5665.017, Time=0.10 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=5488.953, Time=0.08 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=5893.738, Time=0.02 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=5490.435, Time=0.15 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=5490.441, Time=0.30 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.81 sec
#  ARIMA(0,1,1)(0,0,0)[0]             : AIC=5486.955, Time=0.11 sec
#  ARIMA(1,1,1)(0,0,0)[0]             : AIC=5488.437, Time=0.08 sec
#  ARIMA(0,1,2)(0,0,0)[0]             : AIC=5488.442, Time=0.16 sec
#  ARIMA(1,1,0)(0,0,0)[0]             : AIC=5663.024, Time=0.07 sec
#  ARIMA(1,1,2)(0,0,0)[0]             : AIC=inf, Time=0.67 sec
#
# Best model:  ARIMA(0,1,1)(0,0,0)[0]
# Total fit time: 3.197 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=5208.949, Time=1.30 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=5641.944, Time=0.05 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=5347.830, Time=0.10 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=5213.331, Time=0.08 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=5639.944, Time=0.02 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=5206.973, Time=0.90 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=5207.160, Time=0.23 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=5207.568, Time=0.20 sec
#  ARIMA(1,1,3)(0,0,0)[0] intercept   : AIC=5208.957, Time=1.42 sec
#  ARIMA(0,1,3)(0,0,0)[0] intercept   : AIC=5208.633, Time=0.57 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=5209.407, Time=0.29 sec
#  ARIMA(2,1,3)(0,0,0)[0] intercept   : AIC=5207.534, Time=1.57 sec
#  ARIMA(1,1,2)(0,0,0)[0]             : AIC=5204.975, Time=0.29 sec
#  ARIMA(0,1,2)(0,0,0)[0]             : AIC=5205.173, Time=0.06 sec
#  ARIMA(1,1,1)(0,0,0)[0]             : AIC=5205.584, Time=0.07 sec
#  ARIMA(2,1,2)(0,0,0)[0]             : AIC=5206.952, Time=0.30 sec
#  ARIMA(1,1,3)(0,0,0)[0]             : AIC=5206.959, Time=0.66 sec
#  ARIMA(0,1,1)(0,0,0)[0]             : AIC=5211.367, Time=0.10 sec
#  ARIMA(0,1,3)(0,0,0)[0]             : AIC=5206.642, Time=0.23 sec
#  ARIMA(2,1,1)(0,0,0)[0]             : AIC=5207.421, Time=0.17 sec
#  ARIMA(2,1,3)(0,0,0)[0]             : AIC=5205.535, Time=1.00 sec
#
# Best model:  ARIMA(1,1,2)(0,0,0)[0]
# Total fit time: 9.642 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=4432.119, Time=0.25 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=4586.672, Time=0.02 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=4488.667, Time=0.06 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=4513.978, Time=0.04 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=4584.672, Time=0.01 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=4455.284, Time=0.18 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=4489.222, Time=0.28 sec
#  ARIMA(3,1,2)(0,0,0)[0] intercept   : AIC=4434.119, Time=0.24 sec
#  ARIMA(2,1,3)(0,0,0)[0] intercept   : AIC=4434.120, Time=0.57 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=4490.467, Time=0.17 sec
#  ARIMA(1,1,3)(0,0,0)[0] intercept   : AIC=4456.736, Time=0.74 sec
#  ARIMA(3,1,1)(0,0,0)[0] intercept   : AIC=4458.958, Time=0.40 sec
#  ARIMA(3,1,3)(0,0,0)[0] intercept   : AIC=4436.101, Time=0.79 sec
#  ARIMA(2,1,2)(0,0,0)[0]             : AIC=4430.116, Time=0.22 sec
#  ARIMA(1,1,2)(0,0,0)[0]             : AIC=4453.281, Time=0.11 sec
#  ARIMA(2,1,1)(0,0,0)[0]             : AIC=4487.223, Time=0.13 sec
#  ARIMA(3,1,2)(0,0,0)[0]             : AIC=4432.116, Time=0.16 sec
#  ARIMA(2,1,3)(0,0,0)[0]             : AIC=4432.116, Time=0.37 sec
#  ARIMA(1,1,1)(0,0,0)[0]             : AIC=4488.467, Time=0.13 sec
#  ARIMA(1,1,3)(0,0,0)[0]             : AIC=4454.734, Time=0.48 sec
#  ARIMA(3,1,1)(0,0,0)[0]             : AIC=4456.957, Time=0.19 sec
#  ARIMA(3,1,3)(0,0,0)[0]             : AIC=4434.097, Time=0.52 sec
#
# Best model:  ARIMA(2,1,2)(0,0,0)[0]
# Total fit time: 6.083 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.28 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=332.047, Time=0.01 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=331.155, Time=0.02 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=331.207, Time=0.02 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=330.093, Time=0.01 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=333.141, Time=0.03 sec
#
# Best model:  ARIMA(0,1,0)(0,0,0)[0]
# Total fit time: 0.378 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=12164.304, Time=0.64 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=12763.384, Time=0.02 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=12499.304, Time=0.05 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=12159.100, Time=0.15 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=12761.385, Time=0.02 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=12161.081, Time=0.24 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=12161.081, Time=0.26 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=12162.754, Time=0.39 sec
#  ARIMA(0,1,1)(0,0,0)[0]             : AIC=12157.154, Time=0.08 sec
#  ARIMA(1,1,1)(0,0,0)[0]             : AIC=12159.135, Time=0.14 sec
#  ARIMA(0,1,2)(0,0,0)[0]             : AIC=12159.135, Time=0.13 sec
#  ARIMA(1,1,0)(0,0,0)[0]             : AIC=12497.305, Time=0.03 sec
#  ARIMA(1,1,2)(0,0,0)[0]             : AIC=12160.807, Time=0.23 sec
#
# Best model:  ARIMA(0,1,1)(0,0,0)[0]
# Total fit time: 2.388 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=5576.490, Time=0.47 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=5928.662, Time=0.02 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=5801.546, Time=0.11 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=5598.155, Time=0.09 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=5926.681, Time=0.02 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=5579.430, Time=0.22 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=5579.262, Time=0.17 sec
#  ARIMA(3,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.72 sec
#  ARIMA(2,1,3)(0,0,0)[0] intercept   : AIC=inf, Time=2.76 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=5579.949, Time=0.23 sec
#  ARIMA(1,1,3)(0,0,0)[0] intercept   : AIC=5580.001, Time=1.06 sec
#  ARIMA(3,1,1)(0,0,0)[0] intercept   : AIC=5580.805, Time=0.34 sec
#  ARIMA(3,1,3)(0,0,0)[0] intercept   : AIC=5525.368, Time=2.82 sec
#  ARIMA(4,1,3)(0,0,0)[0] intercept   : AIC=inf, Time=3.01 sec
#  ARIMA(3,1,4)(0,0,0)[0] intercept   : AIC=inf, Time=3.26 sec
#  ARIMA(2,1,4)(0,0,0)[0] intercept   : AIC=inf, Time=3.22 sec
#  ARIMA(4,1,2)(0,0,0)[0] intercept   : AIC=5569.731, Time=2.24 sec
#  ARIMA(4,1,4)(0,0,0)[0] intercept   : AIC=inf, Time=3.77 sec
#  ARIMA(3,1,3)(0,0,0)[0]             : AIC=inf, Time=1.98 sec
#
# Best model:  ARIMA(3,1,3)(0,0,0)[0] intercept
# Total fit time: 26.527 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=11184.392, Time=0.82 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=11597.047, Time=0.02 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=11423.282, Time=0.05 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=11194.074, Time=0.14 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=11595.049, Time=0.02 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=11171.599, Time=0.54 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=11180.913, Time=0.18 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=11180.533, Time=0.22 sec
#  ARIMA(1,1,3)(0,0,0)[0] intercept   : AIC=11182.989, Time=1.94 sec
#  ARIMA(0,1,3)(0,0,0)[0] intercept   : AIC=11182.892, Time=0.84 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=11182.279, Time=0.42 sec
#  ARIMA(2,1,3)(0,0,0)[0] intercept   : AIC=11175.960, Time=2.42 sec
#  ARIMA(1,1,2)(0,0,0)[0]             : AIC=11169.800, Time=0.77 sec
#  ARIMA(0,1,2)(0,0,0)[0]             : AIC=11179.003, Time=0.26 sec
#  ARIMA(1,1,1)(0,0,0)[0]             : AIC=11178.640, Time=0.18 sec
#  ARIMA(2,1,2)(0,0,0)[0]             : AIC=11182.640, Time=0.71 sec
#  ARIMA(1,1,3)(0,0,0)[0]             : AIC=11181.086, Time=1.43 sec
#  ARIMA(0,1,1)(0,0,0)[0]             : AIC=11192.110, Time=0.14 sec
#  ARIMA(0,1,3)(0,0,0)[0]             : AIC=11180.985, Time=0.52 sec
#  ARIMA(2,1,1)(0,0,0)[0]             : AIC=11180.399, Time=0.28 sec
#  ARIMA(2,1,3)(0,0,0)[0]             : AIC=11174.005, Time=1.73 sec
#
# Best model:  ARIMA(1,1,2)(0,0,0)[0]
# Total fit time: 13.662 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=4977.258, Time=1.12 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=5519.714, Time=0.06 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=5239.329, Time=0.11 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=4975.406, Time=0.13 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=5517.728, Time=0.03 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=4977.402, Time=0.21 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=4977.402, Time=0.44 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=4977.408, Time=0.76 sec
#  ARIMA(0,1,1)(0,0,0)[0]             : AIC=4973.514, Time=0.12 sec
#  ARIMA(1,1,1)(0,0,0)[0]             : AIC=4975.510, Time=0.09 sec
#  ARIMA(0,1,2)(0,0,0)[0]             : AIC=4975.511, Time=0.07 sec
#  ARIMA(1,1,0)(0,0,0)[0]             : AIC=5237.364, Time=0.04 sec
#  ARIMA(1,1,2)(0,0,0)[0]             : AIC=4975.517, Time=0.16 sec
#
# Best model:  ARIMA(0,1,1)(0,0,0)[0]
# Total fit time: 3.341 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=3835.356, Time=0.33 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=4237.359, Time=0.05 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=4064.875, Time=0.09 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=3834.823, Time=0.10 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=4235.371, Time=0.02 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=3833.941, Time=0.14 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=3835.268, Time=0.19 sec
# ...
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=105.835, Time=0.01 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : AIC=107.461, Time=0.03 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=107.461, Time=0.05 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=105.519, Time=0.02 sec
#  ARIMA(2,0,1)(0,0,0)[0] intercept   : AIC=109.462, Time=0.04 sec
#
# Best model:  ARIMA(1,0,0)(0,0,0)[0] intercept
# Total fit time: 0.680 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=inf, Time=0.23 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=522.772, Time=0.02 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=455.186, Time=0.03 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=488.407, Time=0.04 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=442.323, Time=0.04 sec
#  ARIMA(3,0,0)(0,0,0)[0]             : AIC=427.550, Time=0.05 sec
#  ARIMA(4,0,0)(0,0,0)[0]             : AIC=425.334, Time=0.08 sec
#  ARIMA(5,0,0)(0,0,0)[0]             : AIC=424.953, Time=0.09 sec
#  ARIMA(5,0,1)(0,0,0)[0]             : AIC=425.808, Time=0.18 sec
#  ARIMA(4,0,1)(0,0,0)[0]             : AIC=inf, Time=0.38 sec
#  ARIMA(5,0,0)(0,0,0)[0] intercept   : AIC=415.457, Time=0.19 sec
#  ARIMA(4,0,0)(0,0,0)[0] intercept   : AIC=413.638, Time=0.14 sec
#  ARIMA(3,0,0)(0,0,0)[0] intercept   : AIC=412.029, Time=0.13 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : AIC=413.012, Time=0.09 sec
#  ARIMA(3,0,1)(0,0,0)[0] intercept   : AIC=413.505, Time=0.22 sec
#  ARIMA(2,0,1)(0,0,0)[0] intercept   : AIC=414.225, Time=0.21 sec
#  ARIMA(4,0,1)(0,0,0)[0] intercept   : AIC=415.494, Time=0.27 sec
#
# Best model:  ARIMA(3,0,0)(0,0,0)[0] intercept
# Total fit time: 2.419 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=inf, Time=0.31 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=449.307, Time=0.02 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=344.796, Time=0.03 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=403.280, Time=0.05 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=336.724, Time=0.04 sec
#  ARIMA(3,0,0)(0,0,0)[0]             : AIC=330.630, Time=0.08 sec
#  ARIMA(4,0,0)(0,0,0)[0]             : AIC=328.697, Time=0.15 sec
#  ARIMA(5,0,0)(0,0,0)[0]             : AIC=330.692, Time=0.13 sec
#  ARIMA(4,0,1)(0,0,0)[0]             : AIC=325.828, Time=0.24 sec
#  ARIMA(3,0,1)(0,0,0)[0]             : AIC=327.387, Time=0.21 sec
#  ARIMA(5,0,1)(0,0,0)[0]             : AIC=327.341, Time=0.32 sec
#  ARIMA(4,0,2)(0,0,0)[0]             : AIC=326.122, Time=0.33 sec
#  ARIMA(3,0,2)(0,0,0)[0]             : AIC=inf, Time=0.49 sec
#  ARIMA(5,0,2)(0,0,0)[0]             : AIC=inf, Time=0.72 sec
#  ARIMA(4,0,1)(0,0,0)[0] intercept   : AIC=317.679, Time=0.37 sec
#  ARIMA(3,0,1)(0,0,0)[0] intercept   : AIC=322.435, Time=0.27 sec
#  ARIMA(4,0,0)(0,0,0)[0] intercept   : AIC=321.989, Time=0.11 sec
#  ARIMA(5,0,1)(0,0,0)[0] intercept   : AIC=319.503, Time=0.40 sec
#  ARIMA(4,0,2)(0,0,0)[0] intercept   : AIC=319.491, Time=0.56 sec
#  ARIMA(3,0,0)(0,0,0)[0] intercept   : AIC=320.833, Time=0.10 sec
#  ARIMA(3,0,2)(0,0,0)[0] intercept   : AIC=317.622, Time=0.52 sec
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=323.180, Time=0.23 sec
#  ARIMA(3,0,3)(0,0,0)[0] intercept   : AIC=inf, Time=0.55 sec
#  ARIMA(2,0,1)(0,0,0)[0] intercept   : AIC=321.389, Time=0.15 sec
#  ARIMA(2,0,3)(0,0,0)[0] intercept   : AIC=320.853, Time=0.36 sec
#  ARIMA(4,0,3)(0,0,0)[0] intercept   : AIC=318.219, Time=0.64 sec
#
# Best model:  ARIMA(3,0,2)(0,0,0)[0] intercept
# Total fit time: 7.400 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=219.648, Time=0.22 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=231.072, Time=0.02 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=223.899, Time=0.05 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=216.976, Time=0.05 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=229.078, Time=0.01 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=218.559, Time=0.09 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=217.969, Time=0.06 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=220.033, Time=0.15 sec
#  ARIMA(0,1,1)(0,0,0)[0]             : AIC=215.060, Time=0.03 sec
#  ARIMA(1,1,1)(0,0,0)[0]             : AIC=216.630, Time=0.09 sec
#  ARIMA(0,1,2)(0,0,0)[0]             : AIC=216.021, Time=0.04 sec
#  ARIMA(1,1,0)(0,0,0)[0]             : AIC=221.899, Time=0.03 sec
#  ARIMA(1,1,2)(0,0,0)[0]             : AIC=218.114, Time=0.11 sec
#
# Best model:  ARIMA(0,1,1)(0,0,0)[0]
# Total fit time: 0.969 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=400.407, Time=0.14 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=533.723, Time=0.02 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=441.256, Time=0.03 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=498.158, Time=0.05 sec
#  ARIMA(1,0,2)(0,0,0)[0]             : AIC=399.524, Time=0.12 sec
#  ARIMA(0,0,2)(0,0,0)[0]             : AIC=472.526, Time=0.06 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=inf, Time=0.17 sec
#  ARIMA(1,0,3)(0,0,0)[0]             : AIC=inf, Time=0.32 sec
#  ARIMA(0,0,3)(0,0,0)[0]             : AIC=459.926, Time=0.09 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=399.211, Time=0.11 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=413.256, Time=0.02 sec
#  ARIMA(3,0,1)(0,0,0)[0]             : AIC=inf, Time=0.33 sec
#  ARIMA(3,0,0)(0,0,0)[0]             : AIC=409.308, Time=0.06 sec
#  ARIMA(3,0,2)(0,0,0)[0]             : AIC=402.395, Time=0.27 sec
#  ARIMA(2,0,1)(0,0,0)[0] intercept   : AIC=392.024, Time=0.22 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=391.655, Time=0.11 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=390.958, Time=0.04 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=389.091, Time=0.02 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=390.909, Time=0.05 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[0] intercept
# Total fit time: 2.251 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=576.372, Time=0.35 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=585.192, Time=0.01 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=583.273, Time=0.06 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=580.657, Time=0.04 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=583.349, Time=0.02 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=575.024, Time=0.11 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=575.035, Time=0.08 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=573.117, Time=0.09 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=574.924, Time=0.10 sec
#  ARIMA(2,1,0)(0,0,0)[0] intercept   : AIC=584.651, Time=0.05 sec
#  ARIMA(1,1,1)(0,0,0)[0]             : AIC=572.382, Time=0.03 sec
#  ARIMA(0,1,1)(0,0,0)[0]             : AIC=579.091, Time=0.02 sec
#  ARIMA(1,1,0)(0,0,0)[0]             : AIC=581.475, Time=0.02 sec
#  ARIMA(2,1,1)(0,0,0)[0]             : AIC=574.101, Time=0.06 sec
#  ARIMA(1,1,2)(0,0,0)[0]             : AIC=574.248, Time=0.11 sec
#  ARIMA(0,1,2)(0,0,0)[0]             : AIC=574.003, Time=0.06 sec
#  ARIMA(2,1,0)(0,0,0)[0]             : AIC=582.871, Time=0.05 sec
#  ARIMA(2,1,2)(0,0,0)[0]             : AIC=575.647, Time=0.26 sec
#
# Best model:  ARIMA(1,1,1)(0,0,0)[0]
# Total fit time: 1.525 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=inf, Time=0.28 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=375.089, Time=0.02 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=312.600, Time=0.03 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=342.353, Time=0.04 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=307.906, Time=0.04 sec
#  ARIMA(3,0,0)(0,0,0)[0]             : AIC=304.056, Time=0.06 sec
#  ARIMA(4,0,0)(0,0,0)[0]             : AIC=305.044, Time=0.10 sec
#  ARIMA(3,0,1)(0,0,0)[0]             : AIC=295.767, Time=0.16 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=293.845, Time=0.09 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=294.791, Time=0.05 sec
#  ARIMA(1,0,2)(0,0,0)[0]             : AIC=293.707, Time=0.06 sec
#  ARIMA(0,0,2)(0,0,0)[0]             : AIC=333.426, Time=0.03 sec
#  ARIMA(1,0,3)(0,0,0)[0]             : AIC=295.703, Time=0.21 sec
#  ARIMA(0,0,3)(0,0,0)[0]             : AIC=325.213, Time=0.08 sec
#  ARIMA(2,0,3)(0,0,0)[0]             : AIC=inf, Time=0.38 sec
#  ARIMA(1,0,2)(0,0,0)[0] intercept   : AIC=291.053, Time=0.22 sec
#  ARIMA(0,0,2)(0,0,0)[0] intercept   : AIC=289.205, Time=0.03 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=287.231, Time=0.02 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=289.627, Time=0.01 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=289.182, Time=0.05 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=287.203, Time=0.02 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : AIC=289.193, Time=0.03 sec
#  ARIMA(2,0,1)(0,0,0)[0] intercept   : AIC=291.119, Time=0.10 sec
#
# Best model:  ARIMA(1,0,0)(0,0,0)[0] intercept
# Total fit time: 2.113 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=inf, Time=0.11 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=452.164, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=350.216, Time=0.01 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=408.193, Time=0.02 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=341.432, Time=0.13 sec
#  ARIMA(3,0,0)(0,0,0)[0]             : AIC=338.842, Time=0.03 sec
#  ARIMA(4,0,0)(0,0,0)[0]             : AIC=338.327, Time=0.07 sec
#  ARIMA(5,0,0)(0,0,0)[0]             : AIC=337.019, Time=0.11 sec
#  ARIMA(5,0,1)(0,0,0)[0]             : AIC=332.667, Time=0.23 sec
#  ARIMA(4,0,1)(0,0,0)[0]             : AIC=332.325, Time=0.20 sec
#  ARIMA(3,0,1)(0,0,0)[0]             : AIC=330.917, Time=0.14 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=329.300, Time=0.06 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=327.770, Time=0.04 sec
#  ARIMA(1,0,2)(0,0,0)[0]             : AIC=329.222, Time=0.10 sec
#  ARIMA(0,0,2)(0,0,0)[0]             : AIC=387.892, Time=0.04 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=323.539, Time=0.07 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=321.545, Time=0.02 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=321.397, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=321.562, Time=0.03 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[0] intercept
# Total fit time: 1.441 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=337.687, Time=0.15 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=439.571, Time=0.02 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=355.562, Time=0.03 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=402.531, Time=0.04 sec
#  ARIMA(1,0,2)(0,0,0)[0]             : AIC=334.998, Time=0.14 sec
#  ARIMA(0,0,2)(0,0,0)[0]             : AIC=384.463, Time=0.06 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=333.899, Time=0.08 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=334.873, Time=0.09 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=345.324, Time=0.02 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=329.945, Time=0.07 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=328.996, Time=0.02 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=330.347, Time=0.01 sec
#  ARIMA(0,0,2)(0,0,0)[0] intercept   : AIC=329.876, Time=0.06 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=328.297, Time=0.07 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : AIC=329.854, Time=0.08 sec
#  ARIMA(2,0,1)(0,0,0)[0] intercept   : AIC=331.152, Time=0.12 sec
#
# Best model:  ARIMA(1,0,0)(0,0,0)[0] intercept
# Total fit time: 1.074 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.44 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=364.078, Time=0.02 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=347.417, Time=0.04 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=330.020, Time=0.07 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=362.165, Time=0.01 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=331.226, Time=0.06 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=331.345, Time=0.08 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.38 sec
#  ARIMA(0,1,1)(0,0,0)[0]             : AIC=330.811, Time=0.04 sec
#
# Best model:  ARIMA(0,1,1)(0,0,0)[0] intercept
# Total fit time: 1.159 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=inf, Time=0.27 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=273.017, Time=0.02 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=220.426, Time=0.03 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=250.827, Time=0.04 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=212.925, Time=0.04 sec
#  ARIMA(3,0,0)(0,0,0)[0]             : AIC=207.913, Time=0.09 sec
#  ARIMA(4,0,0)(0,0,0)[0]             : AIC=205.392, Time=0.09 sec
#  ARIMA(5,0,0)(0,0,0)[0]             : AIC=207.242, Time=0.10 sec
#  ARIMA(4,0,1)(0,0,0)[0]             : AIC=206.197, Time=0.13 sec
#  ARIMA(3,0,1)(0,0,0)[0]             : AIC=200.386, Time=0.19 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=inf, Time=0.20 sec
#  ARIMA(3,0,2)(0,0,0)[0]             : AIC=inf, Time=0.30 sec
#  ARIMA(4,0,2)(0,0,0)[0]             : AIC=207.441, Time=0.17 sec
#  ARIMA(3,0,1)(0,0,0)[0] intercept   : AIC=190.803, Time=0.41 sec
#  ARIMA(2,0,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.22 sec
#  ARIMA(3,0,0)(0,0,0)[0] intercept   : AIC=193.363, Time=0.10 sec
#  ARIMA(4,0,1)(0,0,0)[0] intercept   : AIC=192.444, Time=0.51 sec
#  ARIMA(3,0,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.23 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : AIC=191.502, Time=0.04 sec
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.16 sec
#  ARIMA(4,0,0)(0,0,0)[0] intercept   : AIC=195.294, Time=0.18 sec
#  ARIMA(4,0,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.44 sec
#
# Best model:  ARIMA(3,0,1)(0,0,0)[0] intercept
# Total fit time: 3.972 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.20 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=160.455, Time=0.01 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=156.251, Time=0.02 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.06 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=158.562, Time=0.01 sec
#  ARIMA(2,1,0)(0,0,0)[0] intercept   : AIC=150.910, Time=0.03 sec
#  ARIMA(3,1,0)(0,0,0)[0] intercept   : AIC=150.698, Time=0.03 sec
#  ARIMA(4,1,0)(0,0,0)[0] intercept   : AIC=150.676, Time=0.09 sec
#  ARIMA(5,1,0)(0,0,0)[0] intercept   : AIC=152.311, Time=0.14 sec
#  ARIMA(4,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.33 sec
#  ARIMA(3,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.18 sec
#  ARIMA(5,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.51 sec
#  ARIMA(4,1,0)(0,0,0)[0]             : AIC=150.291, Time=0.07 sec
#  ARIMA(3,1,0)(0,0,0)[0]             : AIC=149.732, Time=0.05 sec
#  ARIMA(2,1,0)(0,0,0)[0]             : AIC=149.635, Time=0.05 sec
#  ARIMA(1,1,0)(0,0,0)[0]             : AIC=154.539, Time=0.03 sec
#  ARIMA(2,1,1)(0,0,0)[0]             : AIC=148.806, Time=0.03 sec
#  ARIMA(1,1,1)(0,0,0)[0]             : AIC=148.638, Time=0.04 sec
#  ARIMA(0,1,1)(0,0,0)[0]             : AIC=147.488, Time=0.02 sec
#  ARIMA(0,1,2)(0,0,0)[0]             : AIC=147.821, Time=0.03 sec
#  ARIMA(1,1,2)(0,0,0)[0]             : AIC=151.132, Time=0.03 sec
#
# Best model:  ARIMA(0,1,1)(0,0,0)[0]
# Total fit time: 1.988 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=198.498, Time=0.11 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=234.493, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=200.912, Time=0.01 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=216.360, Time=0.03 sec
#  ARIMA(1,0,2)(0,0,0)[0]             : AIC=inf, Time=0.10 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=202.582, Time=0.04 sec
#  ARIMA(3,0,2)(0,0,0)[0]             : AIC=200.112, Time=0.13 sec
#  ARIMA(2,0,3)(0,0,0)[0]             : AIC=inf, Time=0.28 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=202.170, Time=0.05 sec
#  ARIMA(1,0,3)(0,0,0)[0]             : AIC=198.498, Time=0.23 sec
#  ARIMA(0,0,3)(0,0,0)[0]             : AIC=210.129, Time=0.10 sec
#  ARIMA(1,0,4)(0,0,0)[0]             : AIC=199.808, Time=0.22 sec
#  ARIMA(0,0,2)(0,0,0)[0]             : AIC=208.863, Time=0.06 sec
#  ARIMA(0,0,4)(0,0,0)[0]             : AIC=207.933, Time=0.23 sec
#  ARIMA(2,0,4)(0,0,0)[0]             : AIC=inf, Time=0.31 sec
#  ARIMA(1,0,3)(0,0,0)[0] intercept   : AIC=inf, Time=0.33 sec
#
# Best model:  ARIMA(1,0,3)(0,0,0)[0]
# Total fit time: 2.259 seconds

# %% [markdown]
# You can also experiment with other time series models, ARIMA or traditional ML models.

# %%
# save prediction to file
sample_submission['Target'] = all_forecasts['yhat'].values
sample_submission.drop(['clicks'], inplace=True, axis=1) # you might have to comment this out
sample_submission.to_csv('ccc.csv', index=False)

# %%
#sample_submission.to_csv('cli2pp2.csv', index=False)

# %%
from sklearn.metrics import mean_squared_error
import numpy as np

def calculate_rmse(y_true, y_pred):
    return np.sqrt(mean_squared_error(y_true, y_pred))

# Assuming 'test' dataframe contains actual values for comparison
y_true = train['y'][:370].values  # Replace 'actual_target_column' with the actual column name
y_pred = test['target'].values

rmse = calculate_rmse(y_true, y_pred)
print("Root Mean Squared Error (RMSE):", rmse)
# Out:
# Root Mean Squared Error (RMSE): 83.74531436173734
